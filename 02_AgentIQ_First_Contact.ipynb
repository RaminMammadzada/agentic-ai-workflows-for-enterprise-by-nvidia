# %% [markdown]
# <a href="https://www.nvidia.com/dli"> <img src="images/nvidia_header.png" style="margin-left: -30px; width: 300px; float: left;"> </a>

# %% [markdown]
# # Getting Started with AgentIQ CLI
#
# ## What is AgentIQ?
#
# AgentIQ is a open-source, lightweight library developed by NVIDIA for composing and configuring agents of any framework. It provides MLOps administrators, developers, data solutions engineers, and data scientists with the tools to create workflows that are repeatable and flexible.
#
# Agentic system developers can interact with AgentIQ using a workflow instance that consists of three primary interfaces, which are configurable using a YAML file:
#
# - **Workflow**: The main entry point of an AgentIQ application that orchestrates the agentic system, composed of an arbitrary number of agents and tools across a heterogeneous set of implementations.
#
# - **Tool**: The AgentIQ primitive tools provided to the workflows that agents use or access. They are arbitrarily complex coroutines containing skill implementations that get wrapped in specified LLM frameworks at runtime.
#
# - **LLM**: The core reasoning engines for AgentIQ workflows and can be used to route requests to the appropriate tool. Each LLM comes from a provider (NIM, OpenAI, etc.) and gets wrapped as an LLM framework client at runtime.
#
# AgentIQ can run agent workflows on the command line, serve them as an extensible API, evaluate agents for testing, run deep profiling, and provide observability into the entire agentic pipeline.

# %% [markdown]
# ## AgentIQ First Steps
#
# Before we start building our agentic workflows, let's take a look at the AgentIQ CLI: `aiq`

# %% [markdown]
# ### 1. Checking the AgentIQ Version
#
# Next, we'll check the installed version of AgentIQ to ensure compatibility with the features we'll be using.

# %%
# !aiq --version
# Out:
# aiq, version 1.1.0

# %% [markdown]
# ### 2. Exploring Available Commands
#
# Let's display the main help information for the AgentIQ CLI to see all available commands and their basic usage.

# %%
# !aiq
# Out:
# Usage: aiq [OPTIONS] COMMAND [ARGS]...
#
#   Main entrypoint for the AIQ Toolkit CLI
#
# Options:
#   --version                       Show the version and exit.
#   --log-level [debug|info|warning|error|critical]
#                                   Set the logging level  [default: INFO]
#   --help                          Show this message and exit.
#
# Commands:
#   configure  Configure AIQ Toolkit developer preferences.
#   eval       Evaluate a workflow with the specified dataset.
#   info       Provide information about the local AIQ Toolkit environment.
#   mcp        Run an AIQ Toolkit workflow using the mcp front end.
#   registry   Utility to configure AIQ Toolkit remote registry channels.
#   run        Run an AIQ Toolkit workflow using the console front end.
#   serve      Run an AIQ Toolkit workflow using the fastapi front end.
#   start      Run an AIQ Toolkit workflow using a front end configuration.
#   uninstall  Uninstall an AIQ Toolkit plugin packages from the local...
#   validate   Validate a configuration file
#   workflow   Interact with templated workflows.

# %% [markdown]
# ### 3. Discovering Available Components
#
# Now we'll list all available function components in AgentIQ. The `-t` flag filters by component type (function in this case). This shows what built-in tools we can use in our agent.

# %%
# !aiq info components -t function
# Out:
# 2025-07-11 08:26:05,496 - aiq.runtime.loader - WARNING - Loading module 'aiq.agent.register' from entry point 'aiq_agents' took a long time (398.116350 ms). Ensure all imports are inside your registered functions.
#                            AIQ Toolkit Search Results
# ┏━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┓
# ┃ package        ┃ version ┃ component_type ┃ component_name  ┃ description    ┃
# ┡━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━┩
# │ aiqtoolkit     │ 1.1.0   │ function       │ react_agent     │ Defines an AIQ │
# │                │         │                │                 │ Toolkit        │
# │                │         │                │                 │ function that  │
# │                │         │                │                 │ uses a ReAct   │
# │                │         │                │                 │ Agent performs │
# │                │         │                │                 │ reasoning      │
# │                │         │                │                 │ inbetween tool │
# │                │         │                │                 │ calls, and     │
# │                │         │                │                 │ utilizes the   │
# │                │         │                │                 │     tool names │
# │                │         │                │                 │ and            │
# │                │         │                │                 │ descriptions   │
# │                │         │                │                 │ to select the  │
# │                │         │                │                 │ optimal tool.  │
# │                │         │                │                 │                │
# │                │         │                │                 │   Args:        │
# │                │         │                │                 │     _type      │
# │                │         │                │                 │ (str): The     │
# │                │         │                │                 │ type of the    │
# │                │         │                │                 │ object.        │
# │                │         │                │                 │     tool_names │
# │                │         │                │                 │ (list): The    │
# │                │         │                │                 │ list of tools  │
# │                │         │                │                 │ to provide to  │
# │                │         │                │                 │ the react      │
# │                │         │                │                 │ agent.         │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ None.          │
# │                │         │                │                 │     llm_name   │
# │                │         │                │                 │ (LLMRef): The  │
# │                │         │                │                 │ LLM model to   │
# │                │         │                │                 │ use with the   │
# │                │         │                │                 │ react agent.   │
# │                │         │                │                 │     verbose    │
# │                │         │                │                 │ (bool): Set    │
# │                │         │                │                 │ the verbosity  │
# │                │         │                │                 │ of the react   │
# │                │         │                │                 │ agent's        │
# │                │         │                │                 │ logging.       │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ False.         │
# │                │         │                │                 │     retry_pars │
# │                │         │                │                 │ ing_errors     │
# │                │         │                │                 │ (bool):        │
# │                │         │                │                 │ Specify        │
# │                │         │                │                 │ retrying when  │
# │                │         │                │                 │ encountering   │
# │                │         │                │                 │ parsing        │
# │                │         │                │                 │ errors.        │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ True.          │
# │                │         │                │                 │     max_retrie │
# │                │         │                │                 │ s (int): Sent  │
# │                │         │                │                 │ the number of  │
# │                │         │                │                 │ retries before │
# │                │         │                │                 │ raising a      │
# │                │         │                │                 │ parsing error. │
# │                │         │                │                 │ Defaults to 1. │
# │                │         │                │                 │     include_to │
# │                │         │                │                 │ ol_input_schem │
# │                │         │                │                 │ a_in_tool_desc │
# │                │         │                │                 │ ription        │
# │                │         │                │                 │ (bool):        │
# │                │         │                │                 │ Specify        │
# │                │         │                │                 │ inclusion of   │
# │                │         │                │                 │ tool input     │
# │                │         │                │                 │ schemas in the │
# │                │         │                │                 │ prompt.        │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ True.          │
# │                │         │                │                 │     max_iterat │
# │                │         │                │                 │ ions (int):    │
# │                │         │                │                 │ Number of tool │
# │                │         │                │                 │ calls before   │
# │                │         │                │                 │ stoping the    │
# │                │         │                │                 │ react agent.   │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ 15.            │
# │                │         │                │                 │     descriptio │
# │                │         │                │                 │ n (str): The   │
# │                │         │                │                 │ description of │
# │                │         │                │                 │ this functions │
# │                │         │                │                 │ use. Defaults  │
# │                │         │                │                 │ to "ReAct      │
# │                │         │                │                 │ Agent          │
# │                │         │                │                 │ Workflow".     │
# │                │         │                │                 │     system_pro │
# │                │         │                │                 │ mpt (str |     │
# │                │         │                │                 │ None):         │
# │                │         │                │                 │ Provides the   │
# │                │         │                │                 │ SYSTEM_PROMPT  │
# │                │         │                │                 │ to use with    │
# │                │         │                │                 │ the agent.     │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ None.          │
# │                │         │                │                 │     max_histor │
# │                │         │                │                 │ y (int):       │
# │                │         │                │                 │ Maximum number │
# │                │         │                │                 │ of messages to │
# │                │         │                │                 │ keep in the    │
# │                │         │                │                 │ conversation   │
# │                │         │                │                 │ history.       │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ 15.            │
# │                │         │                │                 │     use_openai │
# │                │         │                │                 │ _api (bool):   │
# │                │         │                │                 │ Use OpenAI API │
# │                │         │                │                 │ for the        │
# │                │         │                │                 │ input/output   │
# │                │         │                │                 │ types to the   │
# │                │         │                │                 │ function. If   │
# │                │         │                │                 │ False, strings │
# │                │         │                │                 │ will be used.  │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ False.         │
# │                │         │                │                 │     additional │
# │                │         │                │                 │ _instructions  │
# │                │         │                │                 │ (str | None):  │
# │                │         │                │                 │ Additional     │
# │                │         │                │                 │ instructions   │
# │                │         │                │                 │ to provide to  │
# │                │         │                │                 │ the agent in   │
# │                │         │                │                 │ addition to    │
# │                │         │                │                 │ the base       │
# │                │         │                │                 │ prompt.        │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ None.          │
# ├────────────────┼─────────┼────────────────┼─────────────────┼────────────────┤
# │ aiqtoolkit     │ 1.1.0   │ function       │ reasoning_agent │ Defines an AIQ │
# │                │         │                │                 │ Toolkit        │
# │                │         │                │                 │ function that  │
# │                │         │                │                 │ performs       │
# │                │         │                │                 │ reasoning on   │
# │                │         │                │                 │ the input      │
# │                │         │                │                 │ data.          │
# │                │         │                │                 │     Output is  │
# │                │         │                │                 │ passed to the  │
# │                │         │                │                 │ next function  │
# │                │         │                │                 │ in the         │
# │                │         │                │                 │ workflow.      │
# │                │         │                │                 │                │
# │                │         │                │                 │     Designed   │
# │                │         │                │                 │ to be used     │
# │                │         │                │                 │ with an        │
# │                │         │                │                 │ InterceptingFu │
# │                │         │                │                 │ nction.        │
# │                │         │                │                 │                │
# │                │         │                │                 │   Args:        │
# │                │         │                │                 │     _type      │
# │                │         │                │                 │ (str): The     │
# │                │         │                │                 │ type of the    │
# │                │         │                │                 │ object.        │
# │                │         │                │                 │     llm_name   │
# │                │         │                │                 │ (LLMRef): The  │
# │                │         │                │                 │ name of the    │
# │                │         │                │                 │ LLM to use for │
# │                │         │                │                 │ reasoning.     │
# │                │         │                │                 │     augmented_ │
# │                │         │                │                 │ fn             │
# │                │         │                │                 │ (FunctionRef): │
# │                │         │                │                 │ The name of    │
# │                │         │                │                 │ the function   │
# │                │         │                │                 │ to reason on.  │
# │                │         │                │                 │     verbose    │
# │                │         │                │                 │ (bool):        │
# │                │         │                │                 │ Whether to log │
# │                │         │                │                 │ detailed       │
# │                │         │                │                 │ information.   │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ False.         │
# │                │         │                │                 │     reasoning_ │
# │                │         │                │                 │ prompt_templat │
# │                │         │                │                 │ e (str): The   │
# │                │         │                │                 │ reasoning      │
# │                │         │                │                 │ model prompt   │
# │                │         │                │                 │ template.      │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ "You are an    │
# │                │         │                │                 │ expert         │
# │                │         │                │                 │ reasoning      │
# │                │         │                │                 │ model task     │
# │                │         │                │                 │ with creating  │
# │                │         │                │                 │ a detailed     │
# │                │         │                │                 │ execution plan │
# │                │         │                │                 │ for a system   │
# │                │         │                │                 │ that has the   │
# │                │         │                │                 │ following      │
# │                │         │                │                 │ description:   │
# │                │         │                │                 │                │
# │                │         │                │                 │ **Description: │
# │                │         │                │                 │ **             │
# │                │         │                │                 │ {augmented_fun │
# │                │         │                │                 │ ction_desc}    │
# │                │         │                │                 │                │
# │                │         │                │                 │ Given the      │
# │                │         │                │                 │ following      │
# │                │         │                │                 │ input and a    │
# │                │         │                │                 │ list of        │
# │                │         │                │                 │ available      │
# │                │         │                │                 │ tools, please  │
# │                │         │                │                 │ provide a      │
# │                │         │                │                 │ detailed       │
# │                │         │                │                 │ step-by-step   │
# │                │         │                │                 │ plan that an   │
# │                │         │                │                 │ instruction    │
# │                │         │                │                 │ following      │
# │                │         │                │                 │ system can use │
# │                │         │                │                 │ to address the │
# │                │         │                │                 │ input. Ensure  │
# │                │         │                │                 │ the plan       │
# │                │         │                │                 │ includes:      │
# │                │         │                │                 │                │
# │                │         │                │                 │ 1. Identifying │
# │                │         │                │                 │ the key        │
# │                │         │                │                 │ components of  │
# │                │         │                │                 │ the input.     │
# │                │         │                │                 │ 2. Determining │
# │                │         │                │                 │ the most       │
# │                │         │                │                 │ suitable tools │
# │                │         │                │                 │ for each task. │
# │                │         │                │                 │ 3. Outlining   │
# │                │         │                │                 │ the sequence   │
# │                │         │                │                 │ of actions to  │
# │                │         │                │                 │ be taken.      │
# │                │         │                │                 │                │
# │                │         │                │                 │ **Input:**     │
# │                │         │                │                 │ {input_text}   │
# │                │         │                │                 │                │
# │                │         │                │                 │ **Tools and    │
# │                │         │                │                 │ description of │
# │                │         │                │                 │ the tool:**    │
# │                │         │                │                 │ {tools}        │
# │                │         │                │                 │                │
# │                │         │                │                 │ An example     │
# │                │         │                │                 │ plan could     │
# │                │         │                │                 │ look like      │
# │                │         │                │                 │ this:          │
# │                │         │                │                 │                │
# │                │         │                │                 │ 1. Call tool A │
# │                │         │                │                 │ with input X   │
# │                │         │                │                 │ 2. Call tool B │
# │                │         │                │                 │ with input Y   │
# │                │         │                │                 │ 3. Interpret   │
# │                │         │                │                 │ the output of  │
# │                │         │                │                 │ tool A and B   │
# │                │         │                │                 │ 4. Return the  │
# │                │         │                │                 │ final result   │
# │                │         │                │                 │                │
# │                │         │                │                 │  **PLAN:**     │
# │                │         │                │                 │ ".             │
# │                │         │                │                 │     instructio │
# │                │         │                │                 │ n_prompt_templ │
# │                │         │                │                 │ ate (str): The │
# │                │         │                │                 │ instruction    │
# │                │         │                │                 │ prompt         │
# │                │         │                │                 │ template.      │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ "Answer the    │
# │                │         │                │                 │ following      │
# │                │         │                │                 │ question based │
# │                │         │                │                 │ on message     │
# │                │         │                │                 │ history:       │
# │                │         │                │                 │ {input_text}   │
# │                │         │                │                 │                │
# │                │         │                │                 │ Here is a plan │
# │                │         │                │                 │ for execution  │
# │                │         │                │                 │ that you could │
# │                │         │                │                 │ use to guide   │
# │                │         │                │                 │ you if you     │
# │                │         │                │                 │ wanted to:     │
# │                │         │                │                 │                │
# │                │         │                │                 │ {reasoning_out │
# │                │         │                │                 │ put}           │
# │                │         │                │                 │                │
# │                │         │                │                 │ NOTE: Remember │
# │                │         │                │                 │ to follow your │
# │                │         │                │                 │ guidance on    │
# │                │         │                │                 │ how to format  │
# │                │         │                │                 │ output, etc.   │
# │                │         │                │                 │                │
# │                │         │                │                 │  You must      │
# │                │         │                │                 │ respond with   │
# │                │         │                │                 │ the answer to  │
# │                │         │                │                 │ the original   │
# │                │         │                │                 │ question       │
# │                │         │                │                 │ directly to    │
# │                │         │                │                 │ the user.".    │
# ├────────────────┼─────────┼────────────────┼─────────────────┼────────────────┤
# │ aiqtoolkit     │ 1.1.0   │ function       │ rewoo_agent     │ Defines an AIQ │
# │                │         │                │                 │ Toolkit        │
# │                │         │                │                 │ function that  │
# │                │         │                │                 │ uses a ReWOO   │
# │                │         │                │                 │ Agent performs │
# │                │         │                │                 │ reasoning      │
# │                │         │                │                 │ inbetween tool │
# │                │         │                │                 │ calls, and     │
# │                │         │                │                 │ utilizes the   │
# │                │         │                │                 │     tool names │
# │                │         │                │                 │ and            │
# │                │         │                │                 │ descriptions   │
# │                │         │                │                 │ to select the  │
# │                │         │                │                 │ optimal tool.  │
# │                │         │                │                 │                │
# │                │         │                │                 │   Args:        │
# │                │         │                │                 │     _type      │
# │                │         │                │                 │ (str): The     │
# │                │         │                │                 │ type of the    │
# │                │         │                │                 │ object.        │
# │                │         │                │                 │     tool_names │
# │                │         │                │                 │ (list): The    │
# │                │         │                │                 │ list of tools  │
# │                │         │                │                 │ to provide to  │
# │                │         │                │                 │ the rewoo      │
# │                │         │                │                 │ agent.         │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ None.          │
# │                │         │                │                 │     llm_name   │
# │                │         │                │                 │ (LLMRef): The  │
# │                │         │                │                 │ LLM model to   │
# │                │         │                │                 │ use with the   │
# │                │         │                │                 │ rewoo agent.   │
# │                │         │                │                 │     verbose    │
# │                │         │                │                 │ (bool): Set    │
# │                │         │                │                 │ the verbosity  │
# │                │         │                │                 │ of the rewoo   │
# │                │         │                │                 │ agent's        │
# │                │         │                │                 │ logging.       │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ False.         │
# │                │         │                │                 │     include_to │
# │                │         │                │                 │ ol_input_schem │
# │                │         │                │                 │ a_in_tool_desc │
# │                │         │                │                 │ ription        │
# │                │         │                │                 │ (bool):        │
# │                │         │                │                 │ Specify        │
# │                │         │                │                 │ inclusion of   │
# │                │         │                │                 │ tool input     │
# │                │         │                │                 │ schemas in the │
# │                │         │                │                 │ prompt.        │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ True.          │
# │                │         │                │                 │     descriptio │
# │                │         │                │                 │ n (str): The   │
# │                │         │                │                 │ description of │
# │                │         │                │                 │ this functions │
# │                │         │                │                 │ use. Defaults  │
# │                │         │                │                 │ to "ReWOO      │
# │                │         │                │                 │ Agent          │
# │                │         │                │                 │ Workflow".     │
# │                │         │                │                 │     planner_pr │
# │                │         │                │                 │ ompt (str |    │
# │                │         │                │                 │ None):         │
# │                │         │                │                 │ Provides the   │
# │                │         │                │                 │ PLANNER_PROMPT │
# │                │         │                │                 │ to use with    │
# │                │         │                │                 │ the agent.     │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ None.          │
# │                │         │                │                 │     solver_pro │
# │                │         │                │                 │ mpt (str |     │
# │                │         │                │                 │ None):         │
# │                │         │                │                 │ Provides the   │
# │                │         │                │                 │ SOLVER_PROMPT  │
# │                │         │                │                 │ to use with    │
# │                │         │                │                 │ the agent.     │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ None.          │
# │                │         │                │                 │     max_histor │
# │                │         │                │                 │ y (int):       │
# │                │         │                │                 │ Maximum number │
# │                │         │                │                 │ of messages to │
# │                │         │                │                 │ keep in the    │
# │                │         │                │                 │ conversation   │
# │                │         │                │                 │ history.       │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ 15.            │
# │                │         │                │                 │     use_openai │
# │                │         │                │                 │ _api (bool):   │
# │                │         │                │                 │ Use OpenAI API │
# │                │         │                │                 │ for the        │
# │                │         │                │                 │ input/output   │
# │                │         │                │                 │ types to the   │
# │                │         │                │                 │ function. If   │
# │                │         │                │                 │ False, strings │
# │                │         │                │                 │ will be used.  │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ False.         │
# │                │         │                │                 │     additional │
# │                │         │                │                 │ _instructions  │
# │                │         │                │                 │ (str | None):  │
# │                │         │                │                 │ Additional     │
# │                │         │                │                 │ instructions   │
# │                │         │                │                 │ to provide to  │
# │                │         │                │                 │ the agent in   │
# │                │         │                │                 │ addition to    │
# │                │         │                │                 │ the base       │
# │                │         │                │                 │ prompt.        │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ None.          │
# ├────────────────┼─────────┼────────────────┼─────────────────┼────────────────┤
# │ aiqtoolkit     │ 1.1.0   │ function       │ tool_calling_ag │ A Tool Calling │
# │                │         │                │ ent             │ Agent requires │
# │                │         │                │                 │ an LLM which   │
# │                │         │                │                 │ supports tool  │
# │                │         │                │                 │ calling. A     │
# │                │         │                │                 │ tool Calling   │
# │                │         │                │                 │ Agent utilizes │
# │                │         │                │                 │ the tool       │
# │                │         │                │                 │     input      │
# │                │         │                │                 │ parameters to  │
# │                │         │                │                 │ select the     │
# │                │         │                │                 │ optimal tool.  │
# │                │         │                │                 │ Supports       │
# │                │         │                │                 │ handling tool  │
# │                │         │                │                 │ errors.        │
# │                │         │                │                 │                │
# │                │         │                │                 │   Args:        │
# │                │         │                │                 │     _type      │
# │                │         │                │                 │ (str): The     │
# │                │         │                │                 │ type of the    │
# │                │         │                │                 │ object.        │
# │                │         │                │                 │     tool_names │
# │                │         │                │                 │ (list): The    │
# │                │         │                │                 │ list of tools  │
# │                │         │                │                 │ to provide to  │
# │                │         │                │                 │ the tool       │
# │                │         │                │                 │ calling agent. │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ None.          │
# │                │         │                │                 │     llm_name   │
# │                │         │                │                 │ (LLMRef): The  │
# │                │         │                │                 │ LLM model to   │
# │                │         │                │                 │ use with the   │
# │                │         │                │                 │ tool calling   │
# │                │         │                │                 │ agent.         │
# │                │         │                │                 │     verbose    │
# │                │         │                │                 │ (bool): Set    │
# │                │         │                │                 │ the verbosity  │
# │                │         │                │                 │ of the react   │
# │                │         │                │                 │ agent's        │
# │                │         │                │                 │ logging.       │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ False.         │
# │                │         │                │                 │     handle_too │
# │                │         │                │                 │ l_errors       │
# │                │         │                │                 │ (bool):        │
# │                │         │                │                 │ Specify        │
# │                │         │                │                 │ ability to     │
# │                │         │                │                 │ handle tool    │
# │                │         │                │                 │ calling        │
# │                │         │                │                 │ errors.        │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ True.          │
# │                │         │                │                 │     descriptio │
# │                │         │                │                 │ n (str):       │
# │                │         │                │                 │ Description of │
# │                │         │                │                 │ this functions │
# │                │         │                │                 │ use. Defaults  │
# │                │         │                │                 │ to "Tool       │
# │                │         │                │                 │ Calling Agent  │
# │                │         │                │                 │ Workflow".     │
# │                │         │                │                 │     max_iterat │
# │                │         │                │                 │ ions (int):    │
# │                │         │                │                 │ Number of tool │
# │                │         │                │                 │ calls before   │
# │                │         │                │                 │ stoping the    │
# │                │         │                │                 │ tool calling   │
# │                │         │                │                 │ agent.         │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ 15.            │
# ├────────────────┼─────────┼────────────────┼─────────────────┼────────────────┤
# │ aiqtoolkit     │ 1.1.0   │ function       │ current_datetim │ Simple tool    │
# │                │         │                │ e               │ which returns  │
# │                │         │                │                 │ the current    │
# │                │         │                │                 │ date and time  │
# │                │         │                │                 │ in human       │
# │                │         │                │                 │ readable       │
# │                │         │                │                 │ format.        │
# │                │         │                │                 │                │
# │                │         │                │                 │   Args:        │
# │                │         │                │                 │     _type      │
# │                │         │                │                 │ (str): The     │
# │                │         │                │                 │ type of the    │
# │                │         │                │                 │ object.        │
# ├────────────────┼─────────┼────────────────┼─────────────────┼────────────────┤
# │ aiqtoolkit     │ 1.1.0   │ function       │ milvus_document │ This tool      │
# │                │         │                │ _search         │ retrieves      │
# │                │         │                │                 │ relevant       │
# │                │         │                │                 │ documents for  │
# │                │         │                │                 │ a given user   │
# │                │         │                │                 │ query. The     │
# │                │         │                │                 │ input query is │
# │                │         │                │                 │ mapped to the  │
# │                │         │                │                 │ most           │
# │                │         │                │                 │ appropriate    │
# │                │         │                │                 │     Milvus     │
# │                │         │                │                 │ collection     │
# │                │         │                │                 │ database. This │
# │                │         │                │                 │ will return    │
# │                │         │                │                 │ relevant       │
# │                │         │                │                 │ documents from │
# │                │         │                │                 │ the selected   │
# │                │         │                │                 │ collection.    │
# │                │         │                │                 │                │
# │                │         │                │                 │   Args:        │
# │                │         │                │                 │     _type      │
# │                │         │                │                 │ (str): The     │
# │                │         │                │                 │ type of the    │
# │                │         │                │                 │ object.        │
# │                │         │                │                 │     base_url   │
# │                │         │                │                 │ (str): The     │
# │                │         │                │                 │ base url used  │
# │                │         │                │                 │ to connect to  │
# │                │         │                │                 │ the milvus     │
# │                │         │                │                 │ database.      │
# │                │         │                │                 │     top_k      │
# │                │         │                │                 │ (int): The     │
# │                │         │                │                 │ number of      │
# │                │         │                │                 │ results to     │
# │                │         │                │                 │ return from    │
# │                │         │                │                 │ the milvus     │
# │                │         │                │                 │ database.      │
# │                │         │                │                 │ Defaults to 4. │
# │                │         │                │                 │     timeout    │
# │                │         │                │                 │ (int): The     │
# │                │         │                │                 │ timeout        │
# │                │         │                │                 │ configuration  │
# │                │         │                │                 │ to use when    │
# │                │         │                │                 │ sending        │
# │                │         │                │                 │ requests.      │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ 60.            │
# │                │         │                │                 │     llm_name   │
# │                │         │                │                 │ (LLMRef): The  │
# │                │         │                │                 │ name of the    │
# │                │         │                │                 │ llm client to  │
# │                │         │                │                 │ instantiate to │
# │                │         │                │                 │ determine most │
# │                │         │                │                 │ appropriate    │
# │                │         │                │                 │ milvus         │
# │                │         │                │                 │ collection.    │
# │                │         │                │                 │     collection │
# │                │         │                │                 │ _names (list): │
# │                │         │                │                 │ The list of    │
# │                │         │                │                 │ available      │
# │                │         │                │                 │ collection     │
# │                │         │                │                 │ names.         │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ ['nvidia_api_c │
# │                │         │                │                 │ atalog'].      │
# │                │         │                │                 │     collection │
# │                │         │                │                 │ _descriptions  │
# │                │         │                │                 │ (list):        │
# │                │         │                │                 │ Collection     │
# │                │         │                │                 │ descriptions   │
# │                │         │                │                 │ that map to    │
# │                │         │                │                 │ collection     │
# │                │         │                │                 │ names by index │
# │                │         │                │                 │ position.      │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ ["Documents    │
# │                │         │                │                 │ about NVIDIA's │
# │                │         │                │                 │ product        │
# │                │         │                │                 │ catalog"].     │
# ├────────────────┼─────────┼────────────────┼─────────────────┼────────────────┤
# │ aiqtoolkit     │ 1.1.0   │ function       │ nvidia_rag      │ Tool used to   │
# │                │         │                │                 │ search the     │
# │                │         │                │                 │ NVIDIA         │
# │                │         │                │                 │ Developer      │
# │                │         │                │                 │ database for   │
# │                │         │                │                 │ documents      │
# │                │         │                │                 │ across a       │
# │                │         │                │                 │ variety of     │
# │                │         │                │                 │ NVIDIA asset   │
# │                │         │                │                 │ types.         │
# │                │         │                │                 │                │
# │                │         │                │                 │   Args:        │
# │                │         │                │                 │     _type      │
# │                │         │                │                 │ (str): The     │
# │                │         │                │                 │ type of the    │
# │                │         │                │                 │ object.        │
# │                │         │                │                 │     base_url   │
# │                │         │                │                 │ (str): The     │
# │                │         │                │                 │ base url to    │
# │                │         │                │                 │ the RAG        │
# ...
# │                │         │                │                 │ client         │
# │                │         │                │                 │ instance from  │
# │                │         │                │                 │ the workflow   │
# │                │         │                │                 │ configuration  │
# │                │         │                │                 │ object.        │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ "saas_memory". │
# ├────────────────┼─────────┼────────────────┼─────────────────┼────────────────┤
# │ aiqtoolkit     │ 1.1.0   │ function       │ delete_memory   │ Function to    │
# │                │         │                │                 │ delete memory  │
# │                │         │                │                 │ from a hosted  │
# │                │         │                │                 │ memory         │
# │                │         │                │                 │ platform.      │
# │                │         │                │                 │                │
# │                │         │                │                 │   Args:        │
# │                │         │                │                 │     _type      │
# │                │         │                │                 │ (str): The     │
# │                │         │                │                 │ type of the    │
# │                │         │                │                 │ object.        │
# │                │         │                │                 │     descriptio │
# │                │         │                │                 │ n (str): The   │
# │                │         │                │                 │ description of │
# │                │         │                │                 │ this           │
# │                │         │                │                 │ function's use │
# │                │         │                │                 │ for tool       │
# │                │         │                │                 │ calling        │
# │                │         │                │                 │ agents.        │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ "Tool to       │
# │                │         │                │                 │ retrieve       │
# │                │         │                │                 │ memory about a │
# │                │         │                │                 │ user's         │
# │                │         │                │                 │ interactions   │
# │                │         │                │                 │ to help answer │
# │                │         │                │                 │ questions in a │
# │                │         │                │                 │ personalized   │
# │                │         │                │                 │ way.".         │
# │                │         │                │                 │     memory     │
# │                │         │                │                 │ (MemoryRef):   │
# │                │         │                │                 │ Instance name  │
# │                │         │                │                 │ of the memory  │
# │                │         │                │                 │ client         │
# │                │         │                │                 │ instance from  │
# │                │         │                │                 │ the workflow   │
# │                │         │                │                 │ configuration  │
# │                │         │                │                 │ object.        │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ "saas_memory". │
# ├────────────────┼─────────┼────────────────┼─────────────────┼────────────────┤
# │ aiqtoolkit     │ 1.1.0   │ function       │ get_memory      │ Function to    │
# │                │         │                │                 │ get memory to  │
# │                │         │                │                 │ a hosted       │
# │                │         │                │                 │ memory         │
# │                │         │                │                 │ platform.      │
# │                │         │                │                 │                │
# │                │         │                │                 │   Args:        │
# │                │         │                │                 │     _type      │
# │                │         │                │                 │ (str): The     │
# │                │         │                │                 │ type of the    │
# │                │         │                │                 │ object.        │
# │                │         │                │                 │     descriptio │
# │                │         │                │                 │ n (str): The   │
# │                │         │                │                 │ description of │
# │                │         │                │                 │ this           │
# │                │         │                │                 │ function's use │
# │                │         │                │                 │ for tool       │
# │                │         │                │                 │ calling        │
# │                │         │                │                 │ agents.        │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ "Tool to       │
# │                │         │                │                 │ retrieve       │
# │                │         │                │                 │ memory about a │
# │                │         │                │                 │ user's         │
# │                │         │                │                 │ interactions   │
# │                │         │                │                 │ to help answer │
# │                │         │                │                 │ questions in a │
# │                │         │                │                 │ personalized   │
# │                │         │                │                 │ way.".         │
# │                │         │                │                 │     memory     │
# │                │         │                │                 │ (MemoryRef):   │
# │                │         │                │                 │ Instance name  │
# │                │         │                │                 │ of the memory  │
# │                │         │                │                 │ client         │
# │                │         │                │                 │ instance from  │
# │                │         │                │                 │ the workflow   │
# │                │         │                │                 │ configuration  │
# │                │         │                │                 │ object.        │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ "saas_memory". │
# ├────────────────┼─────────┼────────────────┼─────────────────┼────────────────┤
# │ aiqtoolkit     │ 1.1.0   │ function       │ tavily_internet │ Tool that      │
# │                │         │                │ _search         │ retrieves      │
# │                │         │                │                 │ relevant       │
# │                │         │                │                 │ contexts from  │
# │                │         │                │                 │ web search     │
# │                │         │                │                 │ (using Tavily) │
# │                │         │                │                 │ for the given  │
# │                │         │                │                 │ question.      │
# │                │         │                │                 │     Requires a │
# │                │         │                │                 │ TAVILY_API_KEY │
# │                │         │                │                 │ .              │
# │                │         │                │                 │                │
# │                │         │                │                 │   Args:        │
# │                │         │                │                 │     _type      │
# │                │         │                │                 │ (str): The     │
# │                │         │                │                 │ type of the    │
# │                │         │                │                 │ object.        │
# │                │         │                │                 │     max_result │
# │                │         │                │                 │ s (int):       │
# │                │         │                │                 │ Description    │
# │                │         │                │                 │ unavailable.   │
# │                │         │                │                 │ Defaults to 3. │
# │                │         │                │                 │     api_key    │
# │                │         │                │                 │ (str):         │
# │                │         │                │                 │ Description    │
# │                │         │                │                 │ unavailable.   │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ "".            │
# ├────────────────┼─────────┼────────────────┼─────────────────┼────────────────┤
# │ aiqtoolkit     │ 1.1.0   │ function       │ wiki_search     │ Tool that      │
# │                │         │                │                 │ retrieves      │
# │                │         │                │                 │ relevant       │
# │                │         │                │                 │ contexts from  │
# │                │         │                │                 │ wikipedia      │
# │                │         │                │                 │ search for the │
# │                │         │                │                 │ given          │
# │                │         │                │                 │ question.      │
# │                │         │                │                 │                │
# │                │         │                │                 │   Args:        │
# │                │         │                │                 │     _type      │
# │                │         │                │                 │ (str): The     │
# │                │         │                │                 │ type of the    │
# │                │         │                │                 │ object.        │
# │                │         │                │                 │     max_result │
# │                │         │                │                 │ s (int):       │
# │                │         │                │                 │ Description    │
# │                │         │                │                 │ unavailable.   │
# │                │         │                │                 │ Defaults to 2. │
# ├────────────────┼─────────┼────────────────┼─────────────────┼────────────────┤
# │ aiqtoolkit     │ 1.1.0   │ function       │ code_generation │ Tool for       │
# │                │         │                │                 │ generating     │
# │                │         │                │                 │ code using the │
# │                │         │                │                 │ configured     │
# │                │         │                │                 │ LLM.           │
# │                │         │                │                 │                │
# │                │         │                │                 │   Args:        │
# │                │         │                │                 │     _type      │
# │                │         │                │                 │ (str): The     │
# │                │         │                │                 │ type of the    │
# │                │         │                │                 │ object.        │
# │                │         │                │                 │     llm_name   │
# │                │         │                │                 │ (LLMRef):      │
# │                │         │                │                 │ Description    │
# │                │         │                │                 │ unavailable.   │
# │                │         │                │                 │     verbose    │
# │                │         │                │                 │ (bool):        │
# │                │         │                │                 │ Description    │
# │                │         │                │                 │ unavailable.   │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ False.         │
# │                │         │                │                 │     programmin │
# │                │         │                │                 │ g_language     │
# │                │         │                │                 │ (str):         │
# │                │         │                │                 │ Description    │
# │                │         │                │                 │ unavailable.   │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ "Python".      │
# │                │         │                │                 │     descriptio │
# │                │         │                │                 │ n (str):       │
# │                │         │                │                 │ Description    │
# │                │         │                │                 │ unavailable.   │
# │                │         │                │                 │ Defaults to    │
# │                │         │                │                 │ "Useful to     │
# │                │         │                │                 │ generate       │
# │                │         │                │                 │ Python code.   │
# │                │         │                │                 │ For any        │
# │                │         │                │                 │ questions      │
# │                │         │                │                 │ about code     │
# │                │         │                │                 │ generation,    │
# │                │         │                │                 │ you must only  │
# │                │         │                │                 │ use this       │
# │                │         │                │                 │ tool!".        │
# ├────────────────┼─────────┼────────────────┼─────────────────┼────────────────┤
# │ simple_llm_cal │ 0.0.0   │ function       │ simple_llm_call │ Description    │
# │ l              │         │                │                 │ unavailable.   │
# │                │         │                │                 │                │
# │                │         │                │                 │   Args:        │
# │                │         │                │                 │     _type      │
# │                │         │                │                 │ (str): The     │
# │                │         │                │                 │ type of the    │
# │                │         │                │                 │ object.        │
# │                │         │                │                 │     llm_name   │
# │                │         │                │                 │ (LLMRef):      │
# │                │         │                │                 │ Description    │
# │                │         │                │                 │ unavailable.   │
# └────────────────┴─────────┴────────────────┴─────────────────┴────────────────┘
# 2025-07-11 08:26:05,825 - aiq.registry_handlers.local.local_handler - INFO - Execution complete.

# %% [markdown]
# ## Summary
#
# In this notebook, we've learned about AgentIQ and explored its basic CLI commands. In the next notebook, we'll create a custom workflow with mathematical tools.
